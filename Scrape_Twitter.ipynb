# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawanss/Peyton-data-viz/blob/main/Scrape_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twitter Data Crawler

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Due Date: Sunday, September 18
# <br>
# <span style="color:red">NOTE: There are always last minute issues submitting the case studies. DO NOT WAIT UNTIL THE LAST MINUTE!</span>

# %% [markdown]
# ## List team members:

# %% [markdown]
# 1. a
# 2. b
# 3. c
# 4. d
# 5. e
# 6. f

# %% [markdown]
# **NOTE**: Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost.

# %% [markdown]
# ## Problem 1: Sampling Twitter Data about a certain topic

# %% [markdown]
# * Select a topic that you are interested in, for example, "Khon Kaen" or "Lisa"
# * Use Twitter scraper to sample a collection of tweets about this topic in real time. (It would be recommended that the number of tweets should be larger than 200, but smaller than 1 million.)
# * Store the tweets you downloaded into a local file (txt, csv, or json file)

# %% [markdown]
# Installing "twitter-scraper-selenium" package to scrape tweets with PyPI (The Python Package Index)
# <br>
# https://pypi.org/project/twitter-scraper-selenium/#keywordJson
# <br>
# Prerequisites for using the package:
# * Internet Connection
# * Python 3.6+
# * Chrome or Firefox browser installed on your machine

# %% [markdown]
# Install the package if your computer has never used

# %% [raw]
# !pip3 install twitter-scraper-selenium

# %% [raw]
# from twitter_scraper_selenium import scrap_profile

# %% [raw]
# Scrap profile's tweets in JSON format:

# %% [raw]
# collect_elon_json = scrap_profile(twitter_username="elonmusk",output_format="json",
#                           browser="chrome",tweets_count=10)
# collect_elon_json

# %% [raw]
# from twitter_scraper_selenium import scrap_keyword

# %% [raw]
# #scrap 10 posts by searching keyword "Thailand" from date 30th August till date 31st August
# collect_thailand = scrap_keyword(keyword="thailand", browser="firefox",
#                                  tweets_count=30, output_format="json", filename="Thailand",
#                                  until="2022-08-31", since="2021-08-30")
# print(collect_thailand)

# %% [raw]
# collect_thailand

# %% [raw]
# import json
# data= json.dumps(collect_thailand)#, indent=1)
#
# file = open('thailand.txt','w')
# file.write(data)
# file.close()

# %% [raw]
# data

# %%
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!ls drive/MyDrive/

# %%
file = open('/content/drive/MyDrive/Classroom/DataWarehouseandBigDataAnalytics/thailand_tweets.txt','r') # rename
foo = file.read()
d = json.loads(foo)

# %%
d
# Out:
# '{"1564764893038882816": {"tweet_id": "1564764893038882816", "username": "matthunter", "name": "MATT HUNT\\u039eR", "profile_picture": "https://twitter.com/matthunter/photo", "replies": 2, "retweets": 1, "likes": 7, "is_retweet": false, "posted_time": "2022-08-30T23:59:57+00:00", "content": "Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand. ", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/matthunter/status/1564764893038882816", "link": ""}, "1564764866598080513": {"tweet_id": "1564764866598080513", "username": "DavSmithVP", "name": "DavSmith / Virtual Photography", "profile_picture": "https://twitter.com/DavSmithVP/photo", "replies": 0, "retweets": 0, "likes": 2, "is_retweet": false, "posted_time": "2022-08-30T23:59:50+00:00", "content": "Tomb Raider Underworld | Thailand \\n#VirtualPhotography \\n@tombraider\\n @crystaldynamics", "hashtags": ["VirtualPhotography"], "mentions": ["tombraider", "crystaldynamics"], "images": ["https://pbs.twimg.com/media/FbcpF-FXkAIlqTS?format=jpg&name=small"], "videos": [], "tweet_url": "https://twitter.com/DavSmithVP/status/1564764866598080513", "link": ""}, "1564764845685280772": {"tweet_id": "1564764845685280772", "username": "DailyPattaya", "name": "The Pattaya Daily", "profile_picture": "https://twitter.com/DailyPattaya/photo", "replies": 0, "retweets": 0, "likes": 0, "is_retweet": false, "posted_time": "2022-08-30T23:59:45+00:00", "content": "The latest The Pattaya Daily! http://thepattayadaily.com Thanks to \\n@PopeKael\\n @ASEANNOWTH\\n #thailand #pattaya", "hashtags": ["thailand", "pattaya"], "mentions": ["PopeKael", "ASEANNOWTH"], "images": [], "videos": [], "tweet_url": "https://twitter.com/DailyPattaya/status/1564764845685280772", "link": ""}, "1564764710804897792": {"tweet_id": "1564764710804897792", "username": "Bryan62766077", "name": "Bryan", "profile_picture": "https://twitter.com/Bryan62766077/photo", "replies": 1, "retweets": 0, "likes": 1, "is_retweet": false, "posted_time": "2022-08-30T23:59:13+00:00", "content": "You can live some places for next to nothing, believe it or not. I pay $300 a month for a really nice apartment in Thailand. All utilities included. No deposit. Close to the beach. Live music clubs everywhere. Meals are about $2", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/Bryan62766077/status/1564764710804897792", "link": ""}, "1564764468277612549": {"tweet_id": "1564764468277612549", "username": "Megan_and_Grrr", "name": "Megan", "profile_picture": "https://twitter.com/Megan_and_Grrr/photo", "replies": 0, "retweets": 0, "likes": 0, "is_retweet": false, "posted_time": "2022-08-30T23:58:15+00:00", "content": "ALIEN HOUSE is a story of love, hope and alien intervention set in Wales, Thailand and Inner Space. It\'s a #fantasy story about #extraterrestrial contact and the conflict between a man and his inner voice or alter ego. William is not sure if he\'s going mad https://smarturl.it/alien-house-eng?IQid=jbmegan\\u2026", "hashtags": ["fantasy", "extraterrestrial"], "mentions": [], "images": ["https://pbs.twimg.com/media/Fbco_bSXEAMcDOZ?format=jpg&name=small"], "videos": [], "tweet_url": "https://twitter.com/Megan_and_Grrr/status/1564764468277612549", "link": ""}, "1564764445825458181": {"tweet_id": "1564764445825458181", "username": "OhmPawatInter", "name": "OhmPawat International", "profile_picture": "https://twitter.com/OhmPawatInter/photo", "replies": 0, "retweets": 99, "likes": 143, "is_retweet": false, "posted_time": "2022-08-30T23:58:10+00:00", "content": "Trend twitter update \\n\\nTop Twitter influencers in Thailand today \\n#4 \\n@ohmpawatt\\nInfluence Score: 19442\\n7 top tweets\\n25182 retweets\\n\\nhttps://etrenders.com/trendsetters/Thailand\\u2026\\n#ohmpawat #\\u0e22\\u0e34\\u0e49\\u0e215\\u0e1e\\u0e31\\u0e19\\u0e02\\u0e2d\\u0e07\\u0e42\\u0e2d\\u0e21\\u0e20\\u0e27\\u0e31\\u0e15", "hashtags": ["4", "ohmpawat" ...

# %% [raw]
# #scrap 10 posts by searching keyword "#lisa" from date 30th August till date 31st August
# collect_lisa = scrap_keyword(keyword="#lisa", browser="firefox",
#                                  tweets_count=10, output_format="json", filename="lisa",
#                                  until="2022-08-31", since="2021-08-30")
# print(collect_lisa)

# %% [markdown]
# Save tweets in JSON to file

# %% [raw]
# import json
# data= json.dumps(collect_elon_json, indent=1)
#
# file = open('ElonMusk.txt','w')
# file.write(data)
# file.close()

# %%
file = open('/content/drive/MyDrive/Classroom/DataWarehouseandBigDataAnalytics/ElonMusk.txt','r')
foo = file.read()
d = json.loads(foo)

# %%
type(d)
# Out:
# str

# %%
d
# Out:
# '{"1615406697849442304": {"tweet_id": "1615406697849442304", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 4293, "retweets": 6386, "likes": 40792, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-17T17:52:24+00:00", "content": "The party is on!!   ", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/elonmusk/status/1615406697849442304", "link": "https://t.co/zoa3qmcXqC"}, "1615398789585731587": {"tweet_id": "1615398789585731587", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 3143, "retweets": 3838, "likes": 16395, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-17T17:20:58+00:00", "content": "Companies in general are missing the incredible opportunity that Twitter provides to reach customers. \\n\\nJust Tweet interesting things! That\\u2019s all it takes.", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/elonmusk/status/1615398789585731587", "link": ""}, "1615397502798409729": {"tweet_id": "1615397502798409729", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 4197, "retweets": 6031, "likes": 32977, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-17T17:15:51+00:00", "content": "The Car Aquatic", "hashtags": [], "mentions": [], "images": ["https://pbs.twimg.com/amplify_video_thumb/1615213540633346048/img/OpcnFGvW_-vLrDPi.jpg"], "videos": ["blob:https://twitter.com/481ef58c-e566-46f2-85c2-c57695ee571d"], "tweet_url": "https://twitter.com/elonmusk/status/1615397502798409729", "link": ""}, "1615194151737520128": {"tweet_id": "1615194151737520128", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 17350, "retweets": 18366, "likes": 147883, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-17T03:47:49+00:00", "content": "Trashing accounts that you hate will cause our algorithm to show you more of those accounts, as it is keying off of your interactions.\\n\\nBasically saying if you love trashing *that* account, then you will probably also love trashing *this* account. Not actually wrong lol.", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/elonmusk/status/1615194151737520128", "link": ""}, "1614851530016067586": {"tweet_id": "1614851530016067586", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 7493, "retweets": 11802, "likes": 138918, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-16T05:06:21+00:00", "content": "Kudos to the BBC for self-labelling its state affiliation", "hashtags": [], "mentions": [], "images": [], "videos": [], "tweet_url": "https://twitter.com/elonmusk/status/1614851530016067586", "link": ""}, "1614794711449079808": {"tweet_id": "1614794711449079808", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 11992, "retweets": 17051, "likes": 157085, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-16T01:20:35+00:00", "content": "And that\\u2019s how we will land on Mars", "hashtags": [], "mentions": [], "images": ["https://pbs.twimg.com/ext_tw_video_thumb/1614791754523496448/pu/img/Ftnq5ZrPI6_ffx8p.jpg"], "videos": ["blob:https://twitter.com/b1610de2-5ef3-45e4-b92d-84afe8917cdf"], "tweet_url": "https://twitter.com/elonmusk/status/1614794711449079808", "link": ""}, "1614775803644116993": {"tweet_id": "1614775803644116993", "username": "elonmusk", "name": "Elon Musk", "profile_picture": "https://twitter.com/elonmusk/photo", "replies": 5391, "retweets": 8972, "likes": 140578, "is_retweet": false, "retweet_link": "", "posted_time": "2023-01-16T00:05:27+00:00", "content": "Falcon Heavy Ascends", "hashtags": [], ...

# %%
elon_json = json.loads(d)
elon_json
# Out:
# {'1615406697849442304': {'tweet_id': '1615406697849442304',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 4293,
#   'retweets': 6386,
#   'likes': 40792,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-17T17:52:24+00:00',
#   'content': 'The party is on!!   ',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1615406697849442304',
#   'link': 'https://t.co/zoa3qmcXqC'},
#  '1615398789585731587': {'tweet_id': '1615398789585731587',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 3143,
#   'retweets': 3838,
#   'likes': 16395,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-17T17:20:58+00:00',
#   'content': 'Companies in general are missing the incredible opportunity that Twitter provides to reach customers. \n\nJust Tweet interesting things! That’s all it takes.',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1615398789585731587',
#   'link': ''},
#  '1615397502798409729': {'tweet_id': '1615397502798409729',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 4197,
#   'retweets': 6031,
#   'likes': 32977,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-17T17:15:51+00:00',
#   'content': 'The Car Aquatic',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/amplify_video_thumb/1615213540633346048/img/OpcnFGvW_-vLrDPi.jpg'],
#   'videos': ['blob:https://twitter.com/481ef58c-e566-46f2-85c2-c57695ee571d'],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1615397502798409729',
#   'link': ''},
#  '1615194151737520128': {'tweet_id': '1615194151737520128',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 17350,
#   'retweets': 18366,
#   'likes': 147883,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-17T03:47:49+00:00',
#   'content': 'Trashing accounts that you hate will cause our algorithm to show you more of those accounts, as it is keying off of your interactions.\n\nBasically saying if you love trashing *that* account, then you will probably also love trashing *this* account. Not actually wrong lol.',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1615194151737520128',
#   'link': ''},
#  '1614851530016067586': {'tweet_id': '1614851530016067586',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 7493,
#   'retweets': 11802,
#   'likes': 138918,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-16T05:06:21+00:00',
#   'content': 'Kudos to the BBC for self-labelling its state affiliation',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1614851530016067586',
#   'link': ''},
#  '1614794711449079808': {'tweet_id': '1614794711449079808',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 11992,
#   'retweets': 17051,
#   'likes': 157085,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-16T01:20:35+00:00',
#   'content': 'And that’s how we will land on Mars',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/ext_tw_video_thumb/1614791754523496448/pu/img/Ftnq5ZrPI6_ffx8p.jpg'],
#   'videos': ['blob:https://twitter.com/b1610de2-5ef3-45e4-b92d-84afe8917cdf'],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1614794711449079808',
#   'link': ''},
#  '1614775803644116993': {'tweet_id': '1614775803644116993',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 5391,
#   'retweets': 8972,
#   'likes': 140578,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-16T00:05:27+00:00',
#   'content': 'Falcon Heavy Ascends',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FmjWB6KaMAAWYnv?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1614775803644116993',
#   'link': ''},
#  '1614761844010528770': {'tweet_id': '1614761844010528770',
#   'username': 'elonmusk',
#   'name': 'Elon Musk',
#   'profile_picture': 'https://twitter.com/elonmusk/photo',
#   'replies': 143082,
#   'retweets': 72384,
#   'likes': 622269,
#   'is_retweet': False,
#   'retweet_link': '',
#   'posted_time': '2023-01-15T23:09:59+00:00',
#   'content': 'Instagram makes people depressed & Twitter makes people angry. Which is better?',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/elonmusk/status/1614761844010528770',
#   'link': ''},
#  '1614760728384401408': {'tweet_id': '1614760728384401408',
#   'username': 'SpaceX',
#   'name': 'SpaceX',
#   'profile_picture': 'https://twitter.com/SpaceX/photo',
#   'replies': 1502,
#   'retweets': 5205,
#   'likes': 36093,
#   'is_retweet': True,
#   'retweet_link': 'https://twitter.com/SpaceX/status/1614760728384401408',
#   'posted_time': '2023-01-15T23:05:33+00:00',
#   'content': 'Falcon Heavy’s side boosters have landed',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/amplify_video_thumb/1614760625313583105/img/ywq1az9vQpwgV0Hz.jpg'],
#   'videos': ['blob:https://twitter.com/b0010a74-21e8-4b46-9bb4-53216dd04c7b'],
#   'tweet_url': 'https://twitter.com/SpaceX/status/1614760728384401408',
#   'link': ''},
#  '1614754358813675520': {'tweet_id': '1614754358813675520',
#   'username': 'SpaceX',
#   'name': 'SpaceX',
#   'profile_picture': 'https://twitter.com/SpaceX/photo',
#   'replies': 1133,
#   'retweets': 3454,
#   'likes': 18207,
#   'is_retweet': True,
#   'retweet_link': 'https://twitter.com/SpaceX/status/1614754358813675520',
#   'posted_time': '2023-01-15T22:40:14+00:00',
#   'content': 'Watch Falcon Heavy launch the USSF-67 mission to orbit → http://spacex.com/launches',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': ['blob:https://twitter.com/be535856-d56a-4c09-b001-3c786c9d299d'],
#   'tweet_url': 'https://twitter.com/SpaceX/status/1614754358813675520',
#   'link': 'https://twitter.com/i/broadcasts/1ynJOadQQnrKR'}}

# %%
elon_json.keys()
# Out:
# dict_keys(['1615406697849442304', '1615398789585731587', '1615397502798409729', '1615194151737520128', '1614851530016067586', '1614794711449079808', '1614775803644116993', '1614761844010528770', '1614760728384401408', '1614754358813675520'])

# %% [markdown]
# Most datasets provide only Tweet ID where we can retrieve tweets from tweet ID as follow.
#
# `twitter.com/anyuser/status/<tweet_id>`

# %% [markdown]
# twitter.com/anyuser/status/1615406697849442304

# %%
first_key = list(elon_json.keys())[0]
elon_json[first_key]
# Out:
# {'tweet_id': '1615406697849442304',
#  'username': 'elonmusk',
#  'name': 'Elon Musk',
#  'profile_picture': 'https://twitter.com/elonmusk/photo',
#  'replies': 4293,
#  'retweets': 6386,
#  'likes': 40792,
#  'is_retweet': False,
#  'retweet_link': '',
#  'posted_time': '2023-01-17T17:52:24+00:00',
#  'content': 'The party is on!!   ',
#  'hashtags': [],
#  'mentions': [],
#  'images': [],
#  'videos': [],
#  'tweet_url': 'https://twitter.com/elonmusk/status/1615406697849442304',
#  'link': 'https://t.co/zoa3qmcXqC'}

# %%
elon_json[first_key].keys()
# Out:
# dict_keys(['tweet_id', 'username', 'name', 'profile_picture', 'replies', 'retweets', 'likes', 'is_retweet', 'retweet_link', 'posted_time', 'content', 'hashtags', 'mentions', 'images', 'videos', 'tweet_url', 'link'])

# %%
elon_json[first_key]['content']
# Out:
# 'The party is on!!   '

# %% [markdown]
# #### Pretty print json/dict object

# %%
import pprint
pprint.pprint(elon_json)
# Out:
# {'1614754358813675520': {'content': 'Watch Falcon Heavy launch the USSF-67 '
#                                     'mission to orbit → '
#                                     'http://spacex.com/launches',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': True,
#                          'likes': 18207,
#                          'link': 'https://twitter.com/i/broadcasts/1ynJOadQQnrKR',
#                          'mentions': [],
#                          'name': 'SpaceX',
#                          'posted_time': '2023-01-15T22:40:14+00:00',
#                          'profile_picture': 'https://twitter.com/SpaceX/photo',
#                          'replies': 1133,
#                          'retweet_link': 'https://twitter.com/SpaceX/status/1614754358813675520',
#                          'retweets': 3454,
#                          'tweet_id': '1614754358813675520',
#                          'tweet_url': 'https://twitter.com/SpaceX/status/1614754358813675520',
#                          'username': 'SpaceX',
#                          'videos': ['blob:https://twitter.com/be535856-d56a-4c09-b001-3c786c9d299d']},
#  '1614760728384401408': {'content': 'Falcon Heavy’s side boosters have landed',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/amplify_video_thumb/1614760625313583105/img/ywq1az9vQpwgV0Hz.jpg'],
#                          'is_retweet': True,
#                          'likes': 36093,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'SpaceX',
#                          'posted_time': '2023-01-15T23:05:33+00:00',
#                          'profile_picture': 'https://twitter.com/SpaceX/photo',
#                          'replies': 1502,
#                          'retweet_link': 'https://twitter.com/SpaceX/status/1614760728384401408',
#                          'retweets': 5205,
#                          'tweet_id': '1614760728384401408',
#                          'tweet_url': 'https://twitter.com/SpaceX/status/1614760728384401408',
#                          'username': 'SpaceX',
#                          'videos': ['blob:https://twitter.com/b0010a74-21e8-4b46-9bb4-53216dd04c7b']},
#  '1614761844010528770': {'content': 'Instagram makes people depressed & '
#                                     'Twitter makes people angry. Which is '
#                                     'better?',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 622269,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-15T23:09:59+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 143082,
#                          'retweet_link': '',
#                          'retweets': 72384,
#                          'tweet_id': '1614761844010528770',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1614761844010528770',
#                          'username': 'elonmusk',
#                          'videos': []},
#  '1614775803644116993': {'content': 'Falcon Heavy Ascends',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/media/FmjWB6KaMAAWYnv?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 140578,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-16T00:05:27+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 5391,
#                          'retweet_link': '',
#                          'retweets': 8972,
#                          'tweet_id': '1614775803644116993',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1614775803644116993',
#                          'username': 'elonmusk',
#                          'videos': []},
#  '1614794711449079808': {'content': 'And that’s how we will land on Mars',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/ext_tw_video_thumb/1614791754523496448/pu/img/Ftnq5ZrPI6_ffx8p.jpg'],
#                          'is_retweet': False,
#                          'likes': 157085,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-16T01:20:35+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 11992,
#                          'retweet_link': '',
#                          'retweets': 17051,
#                          'tweet_id': '1614794711449079808',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1614794711449079808',
#                          'username': 'elonmusk',
#                          'videos': ['blob:https://twitter.com/b1610de2-5ef3-45e4-b92d-84afe8917cdf']},
#  '1614851530016067586': {'content': 'Kudos to the BBC for self-labelling its '
#                                     'state affiliation',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 138918,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-16T05:06:21+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 7493,
#                          'retweet_link': '',
#                          'retweets': 11802,
#                          'tweet_id': '1614851530016067586',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1614851530016067586',
#                          'username': 'elonmusk',
#                          'videos': []},
#  '1615194151737520128': {'content': 'Trashing accounts that you hate will '
#                                     'cause our algorithm to show you more of '
#                                     'those accounts, as it is keying off of '
#                                     'your interactions.\n'
#                                     '\n'
#                                     'Basically saying if you love trashing '
#                                     '*that* account, then you will probably '
#                                     'also love trashing *this* account. Not '
#                                     'actually wrong lol.',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 147883,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-17T03:47:49+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 17350,
#                          'retweet_link': '',
#                          'retweets': 18366,
#                          'tweet_id': '1615194151737520128',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1615194151737520128',
#                          'username': 'elonmusk',
#                          'videos': []},
#  '1615397502798409729': {'content': 'The Car Aquatic',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/amplify_video_thumb/1615213540633346048/img/OpcnFGvW_-vLrDPi.jpg'],
#                          'is_retweet': False,
#                          'likes': 32977,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-17T17:15:51+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 4197,
#                          'retweet_link': '',
#                          'retweets': 6031,
#                          'tweet_id': '1615397502798409729',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1615397502798409729',
#                          'username': 'elonmusk',
#                          'videos': ['blob:https://twitter.com/481ef58c-e566-46f2-85c2-c57695ee571d']},
#  '1615398789585731587': {'content': 'Companies in general are missing the '
#                                     'incredible opportunity that Twitter '
#                                     'provides to reach customers. \n'
#                                     '\n'
#                                     'Just Tweet interesting things! That’s all '
#                                     'it takes.',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 16395,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-17T17:20:58+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 3143,
#                          'retweet_link': '',
#                          'retweets': 3838,
#                          'tweet_id': '1615398789585731587',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1615398789585731587',
#                          'username': 'elonmusk',
#                          'videos': []},
#  '1615406697849442304': {'content': 'The party is on!!   ',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 40792,
#                          'link': 'https://t.co/zoa3qmcXqC',
#                          'mentions': [],
#                          'name': 'Elon Musk',
#                          'posted_time': '2023-01-17T17:52:24+00:00',
#                          'profile_picture': 'https://twitter.com/elonmusk/photo',
#                          'replies': 4293,
#                          'retweet_link': '',
#                          'retweets': 6386,
#                          'tweet_id': '1615406697849442304',
#                          'tweet_url': 'https://twitter.com/elonmusk/status/1615406697849442304',
#                          'username': 'elonmusk',
#                          'videos': []}}

# %% [markdown]
# In fact, `pandas` has `pandas.read_json(<file_dir>)` function to read json file into dataframe

# %%
import pandas as pd
from io import StringIO # using StringIO to prevent ValueError

# %% [raw]
# pd.read_json(StringIO(collect_lisa), orient='index')

# %% [raw]
# pd.read_json(StringIO(collect_thailand), orient='index').head()

# %%
pd.read_json(StringIO(d), orient='index').head()
# Out:
#                                           tweet_id  username       name  \
# 2021-03-10 20:04:57.849442304  1615406697849442304  elonmusk  Elon Musk
# 2021-03-10 17:53:09.585731587  1615398789585731584  elonmusk  Elon Musk
# 2021-03-10 17:31:42.798409729  1615397502798409728  elonmusk  Elon Musk
# 2021-03-08 09:02:31.737520128  1615194151737520128  elonmusk  Elon Musk
# 2021-03-04 09:52:10.016067586  1614851530016067584  elonmusk  Elon Musk
#
#                                                   profile_picture  replies  \
# 2021-03-10 20:04:57.849442304  https://twitter.com/elonmusk/photo     4293
# 2021-03-10 17:53:09.585731587  https://twitter.com/elonmusk/photo     3143
# 2021-03-10 17:31:42.798409729  https://twitter.com/elonmusk/photo     4197
# 2021-03-08 09:02:31.737520128  https://twitter.com/elonmusk/photo    17350
# 2021-03-04 09:52:10.016067586  https://twitter.com/elonmusk/photo     7493
#
#                                retweets   likes  is_retweet retweet_link  \
# 2021-03-10 20:04:57.849442304      6386   40792       False
# 2021-03-10 17:53:09.585731587      3838   16395       False
# 2021-03-10 17:31:42.798409729      6031   32977       False
# 2021-03-08 09:02:31.737520128     18366  147883       False
# 2021-03-04 09:52:10.016067586     11802  138918       False
#
#                                             posted_time  \
# 2021-03-10 20:04:57.849442304 2023-01-17 17:52:24+00:00
# 2021-03-10 17:53:09.585731587 2023-01-17 17:20:58+00:00
# 2021-03-10 17:31:42.798409729 2023-01-17 17:15:51+00:00
# 2021-03-08 09:02:31.737520128 2023-01-17 03:47:49+00:00
# 2021-03-04 09:52:10.016067586 2023-01-16 05:06:21+00:00
#
#                                                                          content  \
# 2021-03-10 20:04:57.849442304                               The party is on!!
# 2021-03-10 17:53:09.585731587  Companies in general are missing the incredibl...
# 2021-03-10 17:31:42.798409729                                    The Car Aquatic
# 2021-03-08 09:02:31.737520128  Trashing accounts that you hate will cause our...
# 2021-03-04 09:52:10.016067586  Kudos to the BBC for self-labelling its state ...
#
#                               hashtags mentions  \
# 2021-03-10 20:04:57.849442304       []       []
# 2021-03-10 17:53:09.585731587       []       []
# 2021-03-10 17:31:42.798409729       []       []
# 2021-03-08 09:02:31.737520128       []       []
# 2021-03-04 09:52:10.016067586       []       []
#
#                                                                           images  \
# 2021-03-10 20:04:57.849442304                                                 []
# 2021-03-10 17:53:09.585731587                                                 []
# 2021-03-10 17:31:42.798409729  [https://pbs.twimg.com/amplify_video_thumb/161...
# 2021-03-08 09:02:31.737520128                                                 []
# 2021-03-04 09:52:10.016067586                                                 []
#
#                                                                           videos  \
# 2021-03-10 20:04:57.849442304                                                 []
# 2021-03-10 17:53:09.585731587                                                 []
# 2021-03-10 17:31:42.798409729  [blob:https://twitter.com/481ef58c-e566-46f2-8...
# 2021-03-08 09:02:31.737520128                                                 []
# 2021-03-04 09:52:10.016067586                                                 []
#
#                                                                        tweet_url  \
# 2021-03-10 20:04:57.849442304  https://twitter.com/elonmusk/status/1615406697...
# 2021-03-10 17:53:09.585731587  https://twitter.com/elonmusk/status/1615398789...
# 2021-03-10 17:31:42.798409729  https://twitter.com/elonmusk/status/1615397502...
# 2021-03-08 09:02:31.737520128  https://twitter.com/elonmusk/status/1615194151...
# 2021-03-04 09:52:10.016067586  https://twitter.com/elonmusk/status/1614851530...
#
#                                                   link
# 2021-03-10 20:04:57.849442304  https://t.co/zoa3qmcXqC
# 2021-03-10 17:53:09.585731587
# 2021-03-10 17:31:42.798409729
# 2021-03-08 09:02:31.737520128
# 2021-03-04 09:52:10.016067586

# %%
contents = " ".join([elon_json[key]['content'] for key in elon_json.keys()])
print(contents)
# Out:
# The party is on!!    Companies in general are missing the incredible opportunity that Twitter provides to reach customers.
#
# Just Tweet interesting things! That’s all it takes. The Car Aquatic Trashing accounts that you hate will cause our algorithm to show you more of those accounts, as it is keying off of your interactions.
#
# Basically saying if you love trashing *that* account, then you will probably also love trashing *this* account. Not actually wrong lol. Kudos to the BBC for self-labelling its state affiliation And that’s how we will land on Mars Falcon Heavy Ascends Instagram makes people depressed & Twitter makes people angry. Which is better? Falcon Heavy’s side boosters have landed Watch Falcon Heavy launch the USSF-67 mission to orbit → http://spacex.com/launches

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(contents)
wordcloud

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Create stopword list:
my_stopwords = set(STOPWORDS)
my_stopwords.update(["will"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=my_stopwords, background_color="white").generate(contents)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
